# %%
# !git clone https://github.com/dzaripov/arch_agent.git
# Out:
# Cloning into 'arch_agent'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 179 (delta 68), reused 147 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (179/179), 4.76 MiB | 20.85 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/arch_agent
# Out:
# /content/arch_agent

# %%
# !uv sync
# Out:
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Resolved 184 packages in 1.91s
# Prepared 173 packages in 2m 18s
# Installed 173 packages in 1.25s
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.0
#  + aiosignal==1.4.0
#  + airportsdata==20250909
#  + alembic==1.17.2
#  + annotated-types==0.7.0
#  + anthropic==0.71.0
#  + anyio==4.11.0
#  + asttokens==3.0.0
#  + attrs==25.4.0
#  + black==25.9.0
#  + blobfile==3.0.0
#  + bottle==0.13.4
#  + build==1.3.0
#  + certifi==2025.10.5
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + click==8.3.0
#  + cloudpickle==3.1.1
#  + colorlog==6.10.1
#  + compressed-tensors==0.12.2
#  + contourpy==1.3.3
#  + cuda-bindings==13.0.2
#  + cuda-pathfinder==1.3.1
#  + cuda-python==13.0.2
#  + cycler==0.12.1
#  + datasets==4.2.0
#  + decorator==5.2.1
#  + decord==0.6.0
#  + dill==0.4.0
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + docstring-parser==0.17.0
#  + dotenv==0.9.9
#  + einops==0.8.1
#  + executing==2.2.1
#  + fastapi==0.119.0
# ...

# %%
# !python llm_optimization_informer_updated.py
# Out:
# Using model: alibaba/tongyi-deepresearch-30b-a3b:free by openrouter
#
#  ====== Iteration 1/10 ======
# LLM suggests trying: {'seq_len': 96, 'label_len': 48, 'pred_len': 24, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 's_layers': '3,2,1', 'd_ff': 2048, 'factor': 5, 'padding': 0, 'distil': True, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'output_attention': False, 'mix': True, 'train_epochs': 6, 'batch_size': 32, 'patience': 3, 'learning_rate': 0.0001, 'lradj': 'type1'}
# Results: {'epochs': [1, 2, 3, 4, 5], 'train_loss': [0.4175, 0.2539, 0.1947, 0.1669, 0.1549], 'train_mae': [0.3717, 0.3251, 0.29, 0.2719, 0.2621], 'val_loss': [0.6797, 0.6344, 0.709, 0.7409, 0.7284], 'val_mae': [0.58, 0.5568, 0.5733, 0.581, 0.5746]}
#
#  ====== Iteration 2/10 ======
# ...
